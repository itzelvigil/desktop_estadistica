# %%
import pandas as pd
from random import seed
from random import randint

# %%
mf = pd.read_csv("Files/Data/Muestra_Final.csv", encoding="latin-1")
mf
# Out:
#      LLEGADA               DISTRITO.LOCAL              MUNICIPIO  SECCION  \
# 0        222            AGUA PRIETA VII              AGUA PRIETA       20
# 1        327            AGUA PRIETA VII              AGUA PRIETA       26
# 2        224            AGUA PRIETA VII       NACOZARI DE GARCIA      158
# 3         59            AGUA PRIETA VII              AGUA PRIETA        3
# 4        309            AGUA PRIETA VII              AGUA PRIETA       30
# ..       ...                          ...                    ...      ...
# 365      147  SAN LUIS RIO COLORADO I      SAN LUIS RIO COLORADO      658
# 366      264  SAN LUIS RIO COLORADO I      SAN LUIS RIO COLORADO      685
# 367      186  SAN LUIS RIO COLORADO I      SAN LUIS RIO COLORADO      727
# 368      320  SAN LUIS RIO COLORADO I      SAN LUIS RIO COLORADO      700
# 369       64  SAN LUIS RIO COLORADO I      SAN LUIS RIO COLORADO      738
#
#         CASILLA  PAN  PRI  PRD  PVEM  PT  ...  ENCUENTRO.SOCIAL  \
# 0    CONTIGUA 5  198   94    6     0   5  ...                 1
# 1    CONTIGUA 2  199   83    4     1   6  ...                 2
# 2        BASICA   19   25    9     3   2  ...                 3
# 3        BASICA  207   78    4     2   5  ...                 1
# 4        BASICA   53   57    0     3   0  ...                 0
# ..          ...  ...  ...  ...   ...  ..  ...               ...
# 365      BASICA   94   59    2     5   0  ...                 3
# 366  CONTIGUA 1  156   82    4     6   1  ...                 7
# 367      BASICA  125   67    2    14   5  ...                 5
# 368      BASICA   78   72    1     6   2  ...                 5
# 369  CONTIGUA 1  151  113    2    38   0  ...                 8
#
#      PRI.PVEM.PANAL  PRI.PVEM  PRI.PANAL  PVEM.PANAL  COALICION  \
# 0                 0         0          0           0         94
# 1                11         1          5           1        131
# 2                 0         0          0           0         31
# 3                 7         1          3           0        112
# 4                 4         1          8           0        102
# ..              ...       ...        ...         ...        ...
# 365               0         0          1           0         71
# 366               0         4          0           0         97
# 367               0         0          0           0         82
# 368               1         4          0           0         85
# 369               1         5          1           1        161
#
#      CANDIDATO.NO.REGISTRADO  VOTOS.NULOS  TOTAL.VOTOS.VALIDOS  \
# 0                          0            2                  309
# 1                          1           13                  346
# 2                          0            0                   75
# 3                          0            9                  331
# 4                          0            1                  155
# ..                       ...          ...                  ...
# 365                        0            3                  177
# 366                        0            9                  280
# 367                        0           11                  248
# 368                        0            1                  181
# 369                        0            5                  347
#
#      VOTACION.TOTAL.EMITIDA
# 0                       311
# 1                       360
# 2                        75
# 3                       340
# 4                       156
# ..                      ...
# 365                     180
# 366                     289
# 367                     259
# 368                     182
# 369                     352
#
# [370 rows x 23 columns]

# %%
ms = mf.sample(92)
mf = mf[~mf.isin(ms)]
mf = mf.loc[mf["LLEGADA"].notnull()]
# ms.to_excel("Files/Exports/PAQUETES.xlsx")
ms.to_csv("Files/Exports/PAQUETES.csv", index=False)
ms
# Out:
#      LLEGADA            DISTRITO.LOCAL       MUNICIPIO  SECCION     CASILLA  \
# 148      228  HERMOSILLO NORESTE X          HERMOSILLO      361  CONTIGUA 1
# 191      339      HERMOSILLO SUR XII        HERMOSILLO      480      BASICA
# 65       183             EMPALME XIV           EMPALME      996  CONTIGUA 1
# 28        92             CABORCA III     BENJAMIN HILL       68  CONTIGUA 1
# 261       50         NOGALES SUR V             NOGALES     1387      BASICA
# ..       ...                       ...             ...      ...         ...
# 123      251    HERMOSILLO COSTA XI         HERMOSILLO     1500      BASICA
# 234       29       NOGALES NORTE IV            NOGALES      194  CONTIGUA 2
# 88       173             GUAYMAS XIII          GUAYMAS     1032      BASICA
# 355       47      PUERTO PEÑASCO II     PUERTO PEÑASCO      637      BASICA
# 220      187       NAVOJOA NORTE XIX           NAVOJOA     1265  CONTIGUA 1
#
#      PAN  PRI  PRD  PVEM  PT  ...  ENCUENTRO.SOCIAL  PRI.PVEM.PANAL  PRI.PVEM  \
# 148  120   97    6     4   2  ...                 0               1         1
# 191  129  130    8     3   7  ...                 5               2         2
# 65   139  143   27    12   4  ...                 2               0         2
# 28   181  120    3     4  10  ...                 6               0         4
# 261   55   88    4     6   2  ...                 3               1         0
# ..   ...  ...  ...   ...  ..  ...               ...             ...       ...
# 123   94   93   12     1   3  ...                 3               0         2
# 234   99   98   10     4   8  ...                 0               0         0
# 88   134  113    5     3   6  ...                 1               3         3
# 355  169  164    1     0   7  ...                 1               2         0
# 220  133  132    4     2   0  ...                 2               1         1
#
#      PRI.PANAL  PVEM.PANAL  COALICION  CANDIDATO.NO.REGISTRADO  VOTOS.NULOS  \
# 148          0           0        104                        0            7
# 191          1           0        142                        2            8
# 65           0           0        159                        0           10
# 28           0           0        135                        0            8
# 261          1           0         96                        0           11
# ..         ...         ...        ...                      ...          ...
# 123          0           0        102                        0            4
# 234          0           0        106                        0           12
# 88           2           0        129                        0            6
# 355          0           0        173                        0           10
# 220          0           0        141                        0            7
#
#      TOTAL.VOTOS.VALIDOS  VOTACION.TOTAL.EMITIDA
# 148                  240                     247
# 191                  304                     314
# 65                   337                     347
# 28                   338                     346
# 261                  175                     186
# ..                   ...                     ...
# 123                  223                     227
# 234                  243                     255
# 88                   292                     298
# 355                  361                     371
# 220                  288                     295
#
# [92 rows x 23 columns]

# %%
random_v = randint(20,100)
if random_v > mf.shape[0]:
    random_v = mf.shape[0]

ms = ms.append(mf.sample(random_v))
mf = mf[~mf.isin(ms)]
mf = mf.loc[mf["LLEGADA"].notnull()]
# ms.to_excel("Files/Exports/PAQUETES.xlsx")
ms.to_csv("Files/Exports/PAQUETES.csv", index=False)
ms
# Out:
#      LLEGADA               DISTRITO.LOCAL              MUNICIPIO  SECCION  \
# 148    228.0     HERMOSILLO NORESTE X                 HERMOSILLO    361.0
# 191    339.0         HERMOSILLO SUR XII               HERMOSILLO    480.0
# 65     183.0                EMPALME XIV                  EMPALME    996.0
# 28      92.0                CABORCA III            BENJAMIN HILL     68.0
# 261     50.0            NOGALES SUR V                    NOGALES   1387.0
# ..       ...                          ...                    ...      ...
# 201    151.0         HERMOSILLO SUR XII               HERMOSILLO    586.0
# 361    152.0  SAN LUIS RIO COLORADO I      SAN LUIS RIO COLORADO    666.0
# 196     43.0         HERMOSILLO SUR XII               HERMOSILLO    548.0
# 214    271.0             HUATABAMPO XXI               HUATABAMPO   1203.0
# 124    184.0       HERMOSILLO COSTA XI                HERMOSILLO   1400.0
#
#         CASILLA    PAN    PRI   PRD  PVEM    PT  ...  ENCUENTRO.SOCIAL  \
# 148  CONTIGUA 1  120.0   97.0   6.0   4.0   2.0  ...               0.0
# 191      BASICA  129.0  130.0   8.0   3.0   7.0  ...               5.0
# 65   CONTIGUA 1  139.0  143.0  27.0  12.0   4.0  ...               2.0
# 28   CONTIGUA 1  181.0  120.0   3.0   4.0  10.0  ...               6.0
# 261      BASICA   55.0   88.0   4.0   6.0   2.0  ...               3.0
# ..          ...    ...    ...   ...   ...   ...  ...               ...
# 201  CONTIGUA 1  126.0  172.0   1.0   6.0   2.0  ...               4.0
# 361  CONTIGUA 1  135.0  110.0   6.0   1.0   3.0  ...               3.0
# 196      BASICA  121.0   71.0   5.0   1.0   4.0  ...               1.0
# 214  CONTIGUA 1  119.0  175.0  13.0   0.0   1.0  ...               0.0
# 124  CONTIGUA 1  118.0  166.0   7.0   4.0   3.0  ...               4.0
#
#      PRI.PVEM.PANAL  PRI.PVEM  PRI.PANAL  PVEM.PANAL  COALICION  \
# 148             1.0       1.0        0.0         0.0      104.0
# 191             2.0       2.0        1.0         0.0      142.0
# 65              0.0       2.0        0.0         0.0      159.0
# 28              0.0       4.0        0.0         0.0      135.0
# 261             1.0       0.0        1.0         0.0       96.0
# ..              ...       ...        ...         ...        ...
# 201             5.0       6.0        2.0         0.0      192.0
# 361             3.0       0.0        0.0         0.0      117.0
# 196             1.0       4.0        2.0         0.0       83.0
# 214             2.0      10.0        1.0         0.0      191.0
# 124             2.0       1.0        0.0         0.0      180.0
#
#      CANDIDATO.NO.REGISTRADO  VOTOS.NULOS  TOTAL.VOTOS.VALIDOS  \
# 148                      0.0          7.0                240.0
# 191                      2.0          8.0                304.0
# 65                       0.0         10.0                337.0
# 28                       0.0          8.0                338.0
# 261                      0.0         11.0                175.0
# ..                       ...          ...                  ...
# 201                      0.0          9.0                328.0
# 361                      0.0          7.0                278.0
# 196                      0.0          8.0                220.0
# 214                      0.0          8.0                326.0
# 124                      1.0          7.0                321.0
#
#      VOTACION.TOTAL.EMITIDA
# 148                   247.0
# 191                   314.0
# 65                    347.0
# 28                    346.0
# 261                   186.0
# ..                      ...
# 201                   337.0
# 361                   285.0
# 196                   228.0
# 214                   334.0
# 124                   329.0
#
# [256 rows x 23 columns]
