# %%
import pandas as pd
from random import seed
from random import randint

# %%
mf = pd.read_csv("Files/Data/Muestra_Final.csv", encoding="latin-1")
mf
# Out:
#      LLEGADA               DISTRITO.LOCAL              MUNICIPIO  SECCION  \
# 0        222            AGUA PRIETA VII              AGUA PRIETA       20
# 1        327            AGUA PRIETA VII              AGUA PRIETA       26
# 2        224            AGUA PRIETA VII       NACOZARI DE GARCIA      158
# 3         59            AGUA PRIETA VII              AGUA PRIETA        3
# 4        309            AGUA PRIETA VII              AGUA PRIETA       30
# ..       ...                          ...                    ...      ...
# 365      147  SAN LUIS RIO COLORADO I      SAN LUIS RIO COLORADO      658
# 366      264  SAN LUIS RIO COLORADO I      SAN LUIS RIO COLORADO      685
# 367      186  SAN LUIS RIO COLORADO I      SAN LUIS RIO COLORADO      727
# 368      320  SAN LUIS RIO COLORADO I      SAN LUIS RIO COLORADO      700
# 369       64  SAN LUIS RIO COLORADO I      SAN LUIS RIO COLORADO      738
#
#         CASILLA  PAN  PRI  PRD  PVEM  PT  ...  ENCUENTRO.SOCIAL  \
# 0    CONTIGUA 5  198   94    6     0   5  ...                 1
# 1    CONTIGUA 2  199   83    4     1   6  ...                 2
# 2        BASICA   19   25    9     3   2  ...                 3
# 3        BASICA  207   78    4     2   5  ...                 1
# 4        BASICA   53   57    0     3   0  ...                 0
# ..          ...  ...  ...  ...   ...  ..  ...               ...
# 365      BASICA   94   59    2     5   0  ...                 3
# 366  CONTIGUA 1  156   82    4     6   1  ...                 7
# 367      BASICA  125   67    2    14   5  ...                 5
# 368      BASICA   78   72    1     6   2  ...                 5
# 369  CONTIGUA 1  151  113    2    38   0  ...                 8
#
#      PRI.PVEM.PANAL  PRI.PVEM  PRI.PANAL  PVEM.PANAL  COALICION  \
# 0                 0         0          0           0         94
# 1                11         1          5           1        131
# 2                 0         0          0           0         31
# 3                 7         1          3           0        112
# 4                 4         1          8           0        102
# ..              ...       ...        ...         ...        ...
# 365               0         0          1           0         71
# 366               0         4          0           0         97
# 367               0         0          0           0         82
# 368               1         4          0           0         85
# 369               1         5          1           1        161
#
#      CANDIDATO.NO.REGISTRADO  VOTOS.NULOS  TOTAL.VOTOS.VALIDOS  \
# 0                          0            2                  309
# 1                          1           13                  346
# 2                          0            0                   75
# 3                          0            9                  331
# 4                          0            1                  155
# ..                       ...          ...                  ...
# 365                        0            3                  177
# 366                        0            9                  280
# 367                        0           11                  248
# 368                        0            1                  181
# 369                        0            5                  347
#
#      VOTACION.TOTAL.EMITIDA
# 0                       311
# 1                       360
# 2                        75
# 3                       340
# 4                       156
# ..                      ...
# 365                     180
# 366                     289
# 367                     259
# 368                     182
# 369                     352
#
# [370 rows x 23 columns]

# %%
ms = mf.sample(92)
mf = mf[~mf.isin(ms)]
mf = mf.loc[mf["LLEGADA"].notnull()]
ms.to_excel("Files/Exports/PAQUETES.xlsx")
ms
# Out:
#      LLEGADA               DISTRITO.LOCAL              MUNICIPIO  SECCION  \
# 212      139             HUATABAMPO XXI               HUATABAMPO     1222
# 64       286                EMPALME XIV                    BACUM      771
# 361      152  SAN LUIS RIO COLORADO I      SAN LUIS RIO COLORADO      666
# 141      361       HERMOSILLO COSTA XI                HERMOSILLO      571
# 347      235         PUERTO PEÑASCO II     SAN LUIS RIO COLORADO      724
# ..       ...                          ...                    ...      ...
# 232      203          NAVOJOA NORTE XIX                  NAVOJOA     1230
# 87        83                GUAYMAS XIII                 GUAYMAS     1073
# 222      145          NAVOJOA NORTE XIX                 QUIRIEGO     1307
# 318       81        OBREGON SURESTE XVI                   CAJEME      902
# 230       93          NAVOJOA NORTE XIX                 QUIRIEGO     1307
#
#         CASILLA  PAN  PRI  PRD  PVEM  PT  ...  ENCUENTRO.SOCIAL  \
# 212  CONTIGUA 1  144  165   21     0   0  ...                 0
# 64   CONTIGUA 1   88  194   97     6   5  ...                 0
# 361  CONTIGUA 1  135  110    6     1   3  ...                 3
# 141  CONTIGUA 2  138   76    6     2   2  ...                 7
# 347  CONTIGUA 6   73   93    4     0   2  ...                 8
# ..          ...  ...  ...  ...   ...  ..  ...               ...
# 232  CONTIGUA 1  168  147    4     0   2  ...                 6
# 87   CONTIGUA 1  172  103   18     3   6  ...                 2
# 222      BASICA  248  182    4     1   4  ...                 1
# 318  CONTIGUA 1   69  103    1     2   5  ...                 4
# 230  CONTIGUA 1  206  212    3     0   3  ...                 0
#
#      PRI.PVEM.PANAL  PRI.PVEM  PRI.PANAL  PVEM.PANAL  COALICION  \
# 212               0         0          0           0        170
# 64                0         0          1           1        206
# 361               3         0          0           0        117
# 141               4         1          0           0         85
# 347               0         3          0           1        104
# ..              ...       ...        ...         ...        ...
# 232               0         3          0           0        150
# 87                0         4          0           0        112
# 222               3         1          1           0        189
# 318               0         1          1           0        109
# 230               0         1          0           0        216
#
#      CANDIDATO.NO.REGISTRADO  VOTOS.NULOS  TOTAL.VOTOS.VALIDOS  \
# 212                        0           14                  339
# 64                         0           16                  409
# 361                        0            7                  278
# 141                        0            7                  248
# 347                        0            5                  206
# ..                       ...          ...                  ...
# 232                        0           13                  336
# 87                         0            4                  323
# 222                        0            1                  446
# 318                        0            4                  198
# 230                        0            2                  428
#
#      VOTACION.TOTAL.EMITIDA
# 212                     353
# 64                      425
# 361                     285
# 141                     255
# 347                     211
# ..                      ...
# 232                     349
# 87                      327
# 222                     447
# 318                     202
# 230                     430
#
# [92 rows x 23 columns]

# %%
random_v = randint(20,100)
if random_v > mf.shape[0]:
    random_v = mf.shape[0]

ms = ms.append(mf.sample(random_v))
mf = mf[~mf.isin(ms)]
mf = mf.loc[mf["LLEGADA"].notnull()]
ms.to_excel("Files/Exports/PAQUETES.xlsx")
ms
# Out:
#      LLEGADA        DISTRITO.LOCAL              MUNICIPIO  SECCION  \
# 33     234.0         CABORCA III                  CABORCA    328.0
# 278    259.0  OBREGON CENTRO XVII                  CAJEME    867.0
# 251    248.0     NOGALES SUR V                    NOGALES   1371.0
# 337    246.0  PUERTO PEÑASCO II     SAN LUIS RIO COLORADO    661.0
# 190    335.0  HERMOSILLO SUR XII               HERMOSILLO    582.0
# ..       ...                   ...                    ...      ...
# 22     109.0         CABORCA III                  CABORCA    305.0
# 305     27.0     OBREGON SUR XV                    CAJEME    901.0
# 91      48.0         GUAYMAS XIII                 GUAYMAS   1059.0
# 220    187.0   NAVOJOA NORTE XIX                  NAVOJOA   1265.0
# 245     13.0   NOGALES NORTE IV                   NOGALES    171.0
#
#               CASILLA    PAN    PRI   PRD  PVEM    PT  ...  ENCUENTRO.SOCIAL  \
# 33   EXTRAORDINARIA 1   45.0   81.0   0.0   1.0   3.0  ...               1.0
# 278        CONTIGUA 1   83.0  121.0  12.0   4.0   1.0  ...               3.0
# 251            BASICA   72.0   88.0   9.0   6.0   7.0  ...              10.0
# 337        CONTIGUA 9   90.0   62.0  12.0   3.0   2.0  ...              12.0
# 190        CONTIGUA 1  103.0  100.0  12.0   5.0   6.0  ...               0.0
# ..                ...    ...    ...   ...   ...   ...  ...               ...
# 22             BASICA  135.0  166.0   6.0   5.0  19.0  ...               6.0
# 305        CONTIGUA 5   65.0  157.0   5.0   0.0   2.0  ...               3.0
# 91         CONTIGUA 1  161.0  101.0   6.0   4.0  19.0  ...               3.0
# 220        CONTIGUA 1  133.0  132.0   4.0   2.0   0.0  ...               2.0
# 245        CONTIGUA 2  114.0  121.0  16.0   1.0   6.0  ...               6.0
#
#      PRI.PVEM.PANAL  PRI.PVEM  PRI.PANAL  PVEM.PANAL  COALICION  \
# 33              1.0       1.0        0.0         0.0       85.0
# 278             1.0       5.0        0.0         0.0      134.0
# 251             0.0       0.0        0.0         0.0       95.0
# 337             0.0       0.0        0.0         0.0       67.0
# 190             1.0       3.0        0.0         0.0      112.0
# ..              ...       ...        ...         ...        ...
# 22              0.0       1.0        0.0         0.0      188.0
# 305             2.0       6.0        0.0         0.0      168.0
# 91              2.0       0.0        0.0         0.0      112.0
# 220             1.0       1.0        0.0         0.0      141.0
# 245             0.0       2.0        0.0         0.0      128.0
#
#      CANDIDATO.NO.REGISTRADO  VOTOS.NULOS  TOTAL.VOTOS.VALIDOS  \
# 33                       0.0          0.0                136.0
# 278                      0.0         11.0                252.0
# 251                      0.0          0.0                199.0
# 337                      0.0          8.0                194.0
# 190                      0.0          2.0                241.0
# ..                       ...          ...                  ...
# 22                       0.0          8.0                368.0
# 305                      2.0          7.0                258.0
# 91                       0.0          3.0                326.0
# 220                      0.0          7.0                288.0
# 245                      1.0          7.0                293.0
#
#      VOTACION.TOTAL.EMITIDA
# 33                    136.0
# 278                   263.0
# 251                   199.0
# 337                   202.0
# 190                   243.0
# ..                      ...
# 22                    376.0
# 305                   267.0
# 91                    329.0
# 220                   295.0
# 245                   301.0
#
# [370 rows x 23 columns]
