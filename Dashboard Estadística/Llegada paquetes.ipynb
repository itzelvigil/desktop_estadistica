# %%
import pandas as pd
from random import seed
from random import randint

# %%
mf = pd.read_csv("Files/Data/Muestra_Final.csv", encoding="latin-1")
mf
# Out:
#      LLEGADA               DISTRITO.LOCAL              MUNICIPIO  SECCION  \
# 0        222            AGUA PRIETA VII              AGUA PRIETA       20
# 1        327            AGUA PRIETA VII              AGUA PRIETA       26
# 2        224            AGUA PRIETA VII       NACOZARI DE GARCIA      158
# 3         59            AGUA PRIETA VII              AGUA PRIETA        3
# 4        309            AGUA PRIETA VII              AGUA PRIETA       30
# ..       ...                          ...                    ...      ...
# 365      147  SAN LUIS RIO COLORADO I      SAN LUIS RIO COLORADO      658
# 366      264  SAN LUIS RIO COLORADO I      SAN LUIS RIO COLORADO      685
# 367      186  SAN LUIS RIO COLORADO I      SAN LUIS RIO COLORADO      727
# 368      320  SAN LUIS RIO COLORADO I      SAN LUIS RIO COLORADO      700
# 369       64  SAN LUIS RIO COLORADO I      SAN LUIS RIO COLORADO      738
#
#         CASILLA  PAN  PRI  PRD  PVEM  PT  ...  ENCUENTRO.SOCIAL  \
# 0    CONTIGUA 5  198   94    6     0   5  ...                 1
# 1    CONTIGUA 2  199   83    4     1   6  ...                 2
# 2        BASICA   19   25    9     3   2  ...                 3
# 3        BASICA  207   78    4     2   5  ...                 1
# 4        BASICA   53   57    0     3   0  ...                 0
# ..          ...  ...  ...  ...   ...  ..  ...               ...
# 365      BASICA   94   59    2     5   0  ...                 3
# 366  CONTIGUA 1  156   82    4     6   1  ...                 7
# 367      BASICA  125   67    2    14   5  ...                 5
# 368      BASICA   78   72    1     6   2  ...                 5
# 369  CONTIGUA 1  151  113    2    38   0  ...                 8
#
#      PRI.PVEM.PANAL  PRI.PVEM  PRI.PANAL  PVEM.PANAL  COALICION  \
# 0                 0         0          0           0         94
# 1                11         1          5           1        131
# 2                 0         0          0           0         31
# 3                 7         1          3           0        112
# 4                 4         1          8           0        102
# ..              ...       ...        ...         ...        ...
# 365               0         0          1           0         71
# 366               0         4          0           0         97
# 367               0         0          0           0         82
# 368               1         4          0           0         85
# 369               1         5          1           1        161
#
#      CANDIDATO.NO.REGISTRADO  VOTOS.NULOS  TOTAL.VOTOS.VALIDOS  \
# 0                          0            2                  309
# 1                          1           13                  346
# 2                          0            0                   75
# 3                          0            9                  331
# 4                          0            1                  155
# ..                       ...          ...                  ...
# 365                        0            3                  177
# 366                        0            9                  280
# 367                        0           11                  248
# 368                        0            1                  181
# 369                        0            5                  347
#
#      VOTACION.TOTAL.EMITIDA
# 0                       311
# 1                       360
# 2                        75
# 3                       340
# 4                       156
# ..                      ...
# 365                     180
# 366                     289
# 367                     259
# 368                     182
# 369                     352
#
# [370 rows x 23 columns]

# %%
ms = mf.sample(92)
mf = mf[~mf.isin(ms)]
mf = mf.loc[mf["LLEGADA"].notnull()]
# ms.to_excel("Files/Exports/PAQUETES.xlsx")
ms.to_csv("Files/Exports/PAQUETES.csv", index=False)
ms
# Out:
#      LLEGADA            DISTRITO.LOCAL       MUNICIPIO  SECCION     CASILLA  \
# 63       294             EMPALME XIV           EMPALME     1007  CONTIGUA 1
# 158       55  HERMOSILLO NORESTE X          HERMOSILLO      343  CONTIGUA 4
# 149      100  HERMOSILLO NORESTE X          HERMOSILLO      344  CONTIGUA 6
# 105      332   HERMOSILLO CENTRO IX         HERMOSILLO      532  CONTIGUA 3
# 328      304     OBREGON SURESTE XVI            CAJEME      782      BASICA
# ..       ...                       ...             ...      ...         ...
# 64       286             EMPALME XIV             BACUM      771  CONTIGUA 1
# 338      331      PUERTO PEÑASCO II     PUERTO PEÑASCO      644  CONTIGUA 2
# 114       86   HERMOSILLO CENTRO IX         HERMOSILLO      467      BASICA
# 148      228  HERMOSILLO NORESTE X          HERMOSILLO      361  CONTIGUA 1
# 36       130             CANANEA VI            CANANEA       73      BASICA
#
#      PAN  PRI  PRD  PVEM  PT  ...  ENCUENTRO.SOCIAL  PRI.PVEM.PANAL  PRI.PVEM  \
# 63   130  126   15     1   6  ...                 1               1         0
# 158  166  172    4     5   9  ...                 3               2         4
# 149  170  238   15     5   4  ...                 6               2         3
# 105  145  195   17     3   7  ...                 7               3         0
# 328   58   80    7     1   1  ...                 3               1         2
# ..   ...  ...  ...   ...  ..  ...               ...             ...       ...
# 64    88  194   97     6   5  ...                 0               0         0
# 338  231  127   13     4   2  ...                 3               2         2
# 114   98   79    7     3   3  ...                 6               1         0
# 148  120   97    6     4   2  ...                 0               1         1
# 36    97  124   19     3   8  ...                 0               6         0
#
#      PRI.PANAL  PVEM.PANAL  COALICION  CANDIDATO.NO.REGISTRADO  VOTOS.NULOS  \
# 63           0           0        133                        0            4
# 158          0           0        193                        2            9
# 149          1           0        250                        1           13
# 105          1           0        207                        1            8
# 328          2           0         88                        0            8
# ..         ...         ...        ...                      ...          ...
# 64           1           1        206                        0           16
# 338          1           0        138                        0            5
# 114          0           0         85                        0            5
# 148          0           0        104                        0            7
# 36           0           0        142                        0            6
#
#      TOTAL.VOTOS.VALIDOS  VOTACION.TOTAL.EMITIDA
# 63                   295                     299
# 158                  384                     395
# 149                  461                     475
# 105                  395                     404
# 328                  167                     175
# ..                   ...                     ...
# 64                   409                     425
# 338                  391                     396
# 114                  204                     209
# 148                  240                     247
# 36                   271                     277
#
# [92 rows x 23 columns]

# %%
random_v = randint(20,100)
if random_v > mf.shape[0]:
    random_v = mf.shape[0]

ms = ms.append(mf.sample(random_v))
mf = mf[~mf.isin(ms)]
mf = mf.loc[mf["LLEGADA"].notnull()]
# ms.to_excel("Files/Exports/PAQUETES.xlsx")
ms.to_csv("Files/Exports/PAQUETES.csv", index=False)
ms
# Out:
#      LLEGADA            DISTRITO.LOCAL    MUNICIPIO  SECCION     CASILLA  \
# 63     294.0             EMPALME XIV        EMPALME   1007.0  CONTIGUA 1
# 158     55.0  HERMOSILLO NORESTE X       HERMOSILLO    343.0  CONTIGUA 4
# 149    100.0  HERMOSILLO NORESTE X       HERMOSILLO    344.0  CONTIGUA 6
# 105    332.0   HERMOSILLO CENTRO IX      HERMOSILLO    532.0  CONTIGUA 3
# 328    304.0     OBREGON SURESTE XVI         CAJEME    782.0      BASICA
# ..       ...                       ...          ...      ...         ...
# 144    282.0  HERMOSILLO NORESTE X       HERMOSILLO    344.0  CONTIGUA 5
# 122    192.0    HERMOSILLO COSTA XI      HERMOSILLO   1474.0      BASICA
# 10     131.0         AGUA PRIETA VII    AGUA PRIETA     16.0      BASICA
# 157     67.0  HERMOSILLO NORESTE X       HERMOSILLO    339.0  CONTIGUA 1
# 285     35.0      OBREGON CENTRO XVII        CAJEME    867.0      BASICA
#
#        PAN    PRI   PRD  PVEM   PT  ...  ENCUENTRO.SOCIAL  PRI.PVEM.PANAL  \
# 63   130.0  126.0  15.0   1.0  6.0  ...               1.0             1.0
# 158  166.0  172.0   4.0   5.0  9.0  ...               3.0             2.0
# 149  170.0  238.0  15.0   5.0  4.0  ...               6.0             2.0
# 105  145.0  195.0  17.0   3.0  7.0  ...               7.0             3.0
# 328   58.0   80.0   7.0   1.0  1.0  ...               3.0             1.0
# ..     ...    ...   ...   ...  ...  ...               ...             ...
# 144  213.0  198.0  19.0   6.0  1.0  ...               9.0             3.0
# 122   93.0  115.0  12.0   3.0  5.0  ...               1.0             1.0
# 10   232.0   73.0   2.0   0.0  4.0  ...               2.0            11.0
# 157  143.0  143.0  16.0   9.0  3.0  ...               2.0             0.0
# 285   70.0  154.0  10.0   4.0  5.0  ...               5.0             0.0
#
#      PRI.PVEM  PRI.PANAL  PVEM.PANAL  COALICION  CANDIDATO.NO.REGISTRADO  \
# 63        0.0        0.0         0.0      133.0                      0.0
# 158       4.0        0.0         0.0      193.0                      2.0
# 149       3.0        1.0         0.0      250.0                      1.0
# 105       0.0        1.0         0.0      207.0                      1.0
# 328       2.0        2.0         0.0       88.0                      0.0
# ..        ...        ...         ...        ...                      ...
# 144       2.0        0.0         0.0      210.0                      0.0
# 122       2.0        1.0         0.0      129.0                      0.0
# 10        0.0        8.0         0.0      129.0                      0.0
# 157       6.0        0.0         0.0      163.0                      0.0
# 285       1.0        1.0         0.0      165.0                      0.0
#
#      VOTOS.NULOS  TOTAL.VOTOS.VALIDOS  VOTACION.TOTAL.EMITIDA
# 63           4.0                295.0                   299.0
# 158          9.0                384.0                   395.0
# 149         13.0                461.0                   475.0
# 105          8.0                395.0                   404.0
# 328          8.0                167.0                   175.0
# ..           ...                  ...                     ...
# 144         17.0                465.0                   482.0
# 122          6.0                251.0                   257.0
# 10           7.0                371.0                   378.0
# 157         12.0                338.0                   350.0
# 285         13.0                273.0                   286.0
#
# [279 rows x 23 columns]
