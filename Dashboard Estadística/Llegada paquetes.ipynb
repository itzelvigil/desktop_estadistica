# %%
import pandas as pd
from random import seed
from random import randint

# %%
mf = pd.read_csv("Files/Data/Muestra_Final.csv", encoding="latin-1")
mf
# Out:
#      LLEGADA               DISTRITO.LOCAL              MUNICIPIO  SECCION  \
# 0        222            AGUA PRIETA VII              AGUA PRIETA       20
# 1        327            AGUA PRIETA VII              AGUA PRIETA       26
# 2        224            AGUA PRIETA VII       NACOZARI DE GARCIA      158
# 3         59            AGUA PRIETA VII              AGUA PRIETA        3
# 4        309            AGUA PRIETA VII              AGUA PRIETA       30
# ..       ...                          ...                    ...      ...
# 365      147  SAN LUIS RIO COLORADO I      SAN LUIS RIO COLORADO      658
# 366      264  SAN LUIS RIO COLORADO I      SAN LUIS RIO COLORADO      685
# 367      186  SAN LUIS RIO COLORADO I      SAN LUIS RIO COLORADO      727
# 368      320  SAN LUIS RIO COLORADO I      SAN LUIS RIO COLORADO      700
# 369       64  SAN LUIS RIO COLORADO I      SAN LUIS RIO COLORADO      738
#
#         CASILLA  PAN  PRI  PRD  PVEM  PT  ...  ENCUENTRO.SOCIAL  \
# 0    CONTIGUA 5  198   94    6     0   5  ...                 1
# 1    CONTIGUA 2  199   83    4     1   6  ...                 2
# 2        BASICA   19   25    9     3   2  ...                 3
# 3        BASICA  207   78    4     2   5  ...                 1
# 4        BASICA   53   57    0     3   0  ...                 0
# ..          ...  ...  ...  ...   ...  ..  ...               ...
# 365      BASICA   94   59    2     5   0  ...                 3
# 366  CONTIGUA 1  156   82    4     6   1  ...                 7
# 367      BASICA  125   67    2    14   5  ...                 5
# 368      BASICA   78   72    1     6   2  ...                 5
# 369  CONTIGUA 1  151  113    2    38   0  ...                 8
#
#      PRI.PVEM.PANAL  PRI.PVEM  PRI.PANAL  PVEM.PANAL  COALICION  \
# 0                 0         0          0           0         94
# 1                11         1          5           1        131
# 2                 0         0          0           0         31
# 3                 7         1          3           0        112
# 4                 4         1          8           0        102
# ..              ...       ...        ...         ...        ...
# 365               0         0          1           0         71
# 366               0         4          0           0         97
# 367               0         0          0           0         82
# 368               1         4          0           0         85
# 369               1         5          1           1        161
#
#      CANDIDATO.NO.REGISTRADO  VOTOS.NULOS  TOTAL.VOTOS.VALIDOS  \
# 0                          0            2                  309
# 1                          1           13                  346
# 2                          0            0                   75
# 3                          0            9                  331
# 4                          0            1                  155
# ..                       ...          ...                  ...
# 365                        0            3                  177
# 366                        0            9                  280
# 367                        0           11                  248
# 368                        0            1                  181
# 369                        0            5                  347
#
#      VOTACION.TOTAL.EMITIDA
# 0                       311
# 1                       360
# 2                        75
# 3                       340
# 4                       156
# ..                      ...
# 365                     180
# 366                     289
# 367                     259
# 368                     182
# 369                     352
#
# [370 rows x 23 columns]

# %%
ms = mf.sample(92)
mf = mf[~mf.isin(ms)]
mf = mf.loc[mf["LLEGADA"].notnull()]
# ms.to_excel("Files/Exports/PAQUETES.xlsx")
ms.to_csv("Files/Exports/PAQUETES.csv", index=False)
ms
# Out:
#      LLEGADA               DISTRITO.LOCAL              MUNICIPIO  SECCION  \
# 272      216         OBREGON CENTRO XVII                  CAJEME      961
# 148      228     HERMOSILLO NORESTE X                 HERMOSILLO      361
# 222      145          NAVOJOA NORTE XIX                 QUIRIEGO     1307
# 294       39          OBREGON NORTE XVIII                 CAJEME      952
# 29        88                CABORCA III                  CABORCA      314
# ..       ...                          ...                    ...      ...
# 65       183                EMPALME XIV                  EMPALME      996
# 233      348          NAVOJOA NORTE XIX                 QUIRIEGO     1307
# 361      152  SAN LUIS RIO COLORADO I      SAN LUIS RIO COLORADO      666
# 85       223                GUAYMAS XIII                 GUAYMAS     1082
# 135      338       HERMOSILLO COSTA XI                HERMOSILLO     1475
#
#               CASILLA  PAN  PRI  PRD  PVEM  PT  ...  ENCUENTRO.SOCIAL  \
# 272            BASICA  195  150    1     1   3  ...                 0
# 148        CONTIGUA 1  120   97    6     4   2  ...                 0
# 222            BASICA  248  182    4     1   4  ...                 1
# 294  EXTRAORDINARIA 1   78   78    5     1   4  ...                 1
# 29         CONTIGUA 2  145  202    5     3   9  ...                 6
# ..                ...  ...  ...  ...   ...  ..  ...               ...
# 65         CONTIGUA 1  139  143   27    12   4  ...                 2
# 233        CONTIGUA 2  214  180    4     0   1  ...                 1
# 361        CONTIGUA 1  135  110    6     1   3  ...                 3
# 85         CONTIGUA 2  143  109    8     1   5  ...                 3
# 135            BASICA   33   42    6     2   3  ...                 1
#
#      PRI.PVEM.PANAL  PRI.PVEM  PRI.PANAL  PVEM.PANAL  COALICION  \
# 272               0         8          0           0        160
# 148               1         1          0           0        104
# 222               3         1          1           0        189
# 294               0         3          1           0         92
# 29                2         0          0           0        213
# ..              ...       ...        ...         ...        ...
# 65                0         2          0           0        159
# 233               1         2          0           0        186
# 361               3         0          0           0        117
# 85                2         0          1           0        116
# 135               0         0          0           0         45
#
#      CANDIDATO.NO.REGISTRADO  VOTOS.NULOS  TOTAL.VOTOS.VALIDOS  \
# 272                        0            3                  370
# 148                        0            7                  240
# 222                        0            1                  446
# 294                        0            8                  187
# 29                         0            9                  402
# ..                       ...          ...                  ...
# 65                         0           10                  337
# 233                        0            1                  406
# 361                        0            7                  278
# 85                         2            8                  284
# 135                        0            3                   91
#
#      VOTACION.TOTAL.EMITIDA
# 272                     373
# 148                     247
# 222                     447
# 294                     195
# 29                      411
# ..                      ...
# 65                      347
# 233                     407
# 361                     285
# 85                      294
# 135                      94
#
# [92 rows x 23 columns]

# %%
random_v = randint(20,100)
if random_v > mf.shape[0]:
    random_v = mf.shape[0]

ms = ms.append(mf.sample(random_v))
mf = mf[~mf.isin(ms)]
mf = mf.loc[mf["LLEGADA"].notnull()]
# ms.to_excel("Files/Exports/PAQUETES.xlsx")
ms.to_csv("Files/Exports/PAQUETES.csv", index=False)
ms
# Out:
#      LLEGADA               DISTRITO.LOCAL              MUNICIPIO  SECCION  \
# 272    216.0         OBREGON CENTRO XVII                  CAJEME    961.0
# 148    228.0     HERMOSILLO NORESTE X                 HERMOSILLO    361.0
# 222    145.0          NAVOJOA NORTE XIX                 QUIRIEGO   1307.0
# 294     39.0          OBREGON NORTE XVIII                 CAJEME    952.0
# 29      88.0                CABORCA III                  CABORCA    314.0
# ..       ...                          ...                    ...      ...
# 365    147.0  SAN LUIS RIO COLORADO I      SAN LUIS RIO COLORADO    658.0
# 123    251.0       HERMOSILLO COSTA XI                HERMOSILLO   1500.0
# 91      48.0                GUAYMAS XIII                 GUAYMAS   1059.0
# 4      309.0            AGUA PRIETA VII              AGUA PRIETA     30.0
# 277    134.0         OBREGON CENTRO XVII                  CAJEME    776.0
#
#               CASILLA    PAN    PRI   PRD  PVEM    PT  ...  ENCUENTRO.SOCIAL  \
# 272            BASICA  195.0  150.0   1.0   1.0   3.0  ...               0.0
# 148        CONTIGUA 1  120.0   97.0   6.0   4.0   2.0  ...               0.0
# 222            BASICA  248.0  182.0   4.0   1.0   4.0  ...               1.0
# 294  EXTRAORDINARIA 1   78.0   78.0   5.0   1.0   4.0  ...               1.0
# 29         CONTIGUA 2  145.0  202.0   5.0   3.0   9.0  ...               6.0
# ..                ...    ...    ...   ...   ...   ...  ...               ...
# 365            BASICA   94.0   59.0   2.0   5.0   0.0  ...               3.0
# 123            BASICA   94.0   93.0  12.0   1.0   3.0  ...               3.0
# 91         CONTIGUA 1  161.0  101.0   6.0   4.0  19.0  ...               3.0
# 4              BASICA   53.0   57.0   0.0   3.0   0.0  ...               0.0
# 277            BASICA  113.0  278.0  10.0   4.0   6.0  ...               1.0
#
#      PRI.PVEM.PANAL  PRI.PVEM  PRI.PANAL  PVEM.PANAL  COALICION  \
# 272             0.0       8.0        0.0         0.0      160.0
# 148             1.0       1.0        0.0         0.0      104.0
# 222             3.0       1.0        1.0         0.0      189.0
# 294             0.0       3.0        1.0         0.0       92.0
# 29              2.0       0.0        0.0         0.0      213.0
# ..              ...       ...        ...         ...        ...
# 365             0.0       0.0        1.0         0.0       71.0
# 123             0.0       2.0        0.0         0.0      102.0
# 91              2.0       0.0        0.0         0.0      112.0
# 4               4.0       1.0        8.0         0.0      102.0
# 277             3.0       1.0        0.0         0.0      286.0
#
#      CANDIDATO.NO.REGISTRADO  VOTOS.NULOS  TOTAL.VOTOS.VALIDOS  \
# 272                      0.0          3.0                370.0
# 148                      0.0          7.0                240.0
# 222                      0.0          1.0                446.0
# 294                      0.0          8.0                187.0
# 29                       0.0          9.0                402.0
# ..                       ...          ...                  ...
# 365                      0.0          3.0                177.0
# 123                      0.0          4.0                223.0
# 91                       0.0          3.0                326.0
# 4                        0.0          1.0                155.0
# 277                      0.0         15.0                434.0
#
#      VOTACION.TOTAL.EMITIDA
# 272                   373.0
# 148                   247.0
# 222                   447.0
# 294                   195.0
# 29                    411.0
# ..                      ...
# 365                   180.0
# 123                   227.0
# 91                    329.0
# 4                     156.0
# 277                   449.0
#
# [305 rows x 23 columns]
