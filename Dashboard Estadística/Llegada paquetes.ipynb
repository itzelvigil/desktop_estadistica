# %%
import pandas as pd
from random import seed
from random import randint

# %%
mf = pd.read_csv("Files/Data/Muestra_Final.csv", encoding="latin-1")
mf
# Out:
#      LLEGADA               DISTRITO.LOCAL              MUNICIPIO  SECCION  \
# 0        222            AGUA PRIETA VII              AGUA PRIETA       20
# 1        327            AGUA PRIETA VII              AGUA PRIETA       26
# 2        224            AGUA PRIETA VII       NACOZARI DE GARCIA      158
# 3         59            AGUA PRIETA VII              AGUA PRIETA        3
# 4        309            AGUA PRIETA VII              AGUA PRIETA       30
# ..       ...                          ...                    ...      ...
# 365      147  SAN LUIS RIO COLORADO I      SAN LUIS RIO COLORADO      658
# 366      264  SAN LUIS RIO COLORADO I      SAN LUIS RIO COLORADO      685
# 367      186  SAN LUIS RIO COLORADO I      SAN LUIS RIO COLORADO      727
# 368      320  SAN LUIS RIO COLORADO I      SAN LUIS RIO COLORADO      700
# 369       64  SAN LUIS RIO COLORADO I      SAN LUIS RIO COLORADO      738
#
#         CASILLA  PAN  PRI  PRD  PVEM  PT  ...  ENCUENTRO.SOCIAL  \
# 0    CONTIGUA 5  198   94    6     0   5  ...                 1
# 1    CONTIGUA 2  199   83    4     1   6  ...                 2
# 2        BASICA   19   25    9     3   2  ...                 3
# 3        BASICA  207   78    4     2   5  ...                 1
# 4        BASICA   53   57    0     3   0  ...                 0
# ..          ...  ...  ...  ...   ...  ..  ...               ...
# 365      BASICA   94   59    2     5   0  ...                 3
# 366  CONTIGUA 1  156   82    4     6   1  ...                 7
# 367      BASICA  125   67    2    14   5  ...                 5
# 368      BASICA   78   72    1     6   2  ...                 5
# 369  CONTIGUA 1  151  113    2    38   0  ...                 8
#
#      PRI.PVEM.PANAL  PRI.PVEM  PRI.PANAL  PVEM.PANAL  COALICION  \
# 0                 0         0          0           0         94
# 1                11         1          5           1        131
# 2                 0         0          0           0         31
# 3                 7         1          3           0        112
# 4                 4         1          8           0        102
# ..              ...       ...        ...         ...        ...
# 365               0         0          1           0         71
# 366               0         4          0           0         97
# 367               0         0          0           0         82
# 368               1         4          0           0         85
# 369               1         5          1           1        161
#
#      CANDIDATO.NO.REGISTRADO  VOTOS.NULOS  TOTAL.VOTOS.VALIDOS  \
# 0                          0            2                  309
# 1                          1           13                  346
# 2                          0            0                   75
# 3                          0            9                  331
# 4                          0            1                  155
# ..                       ...          ...                  ...
# 365                        0            3                  177
# 366                        0            9                  280
# 367                        0           11                  248
# 368                        0            1                  181
# 369                        0            5                  347
#
#      VOTACION.TOTAL.EMITIDA
# 0                       311
# 1                       360
# 2                        75
# 3                       340
# 4                       156
# ..                      ...
# 365                     180
# 366                     289
# 367                     259
# 368                     182
# 369                     352
#
# [370 rows x 23 columns]

# %%
ms = mf.sample(92)
mf = mf[~mf.isin(ms)]
mf = mf.loc[mf["LLEGADA"].notnull()]
# ms.to_excel("Files/Exports/PAQUETES.xlsx")
ms.to_csv("Files/Exports/PAQUETES.csv", index=False)
ms
# Out:
#      LLEGADA            DISTRITO.LOCAL       MUNICIPIO  SECCION     CASILLA  \
# 97       174             GUAYMAS XIII          GUAYMAS     1083      BASICA
# 84       127             GUAYMAS XIII          GUAYMAS     1059      BASICA
# 327       26     OBREGON SURESTE XVI            CAJEME      904  CONTIGUA 2
# 295      118       OBREGON NORTE XVIII        ARIVECHI       39      BASICA
# 120      175   HERMOSILLO CENTRO IX         HERMOSILLO      445      BASICA
# ..       ...                       ...             ...      ...         ...
# 195       28      HERMOSILLO SUR XII        HERMOSILLO      485  CONTIGUA 1
# 233      348       NAVOJOA NORTE XIX          QUIRIEGO     1307  CONTIGUA 2
# 157       67  HERMOSILLO NORESTE X          HERMOSILLO      339  CONTIGUA 1
# 95       316             GUAYMAS XIII          GUAYMAS     1090      BASICA
# 338      331      PUERTO PEÑASCO II     PUERTO PEÑASCO      644  CONTIGUA 2
#
#      PAN  PRI  PRD  PVEM  PT  ...  ENCUENTRO.SOCIAL  PRI.PVEM.PANAL  PRI.PVEM  \
# 97   114   64    2     2  17  ...                 1               1         1
# 84   169  152   11     0  13  ...                 2               0         0
# 327   76  104    3     3   0  ...                 5               0         1
# 295   85  116    1     1   1  ...                 0               2         0
# 120  180  132    7     2   5  ...                 2               6         6
# ..   ...  ...  ...   ...  ..  ...               ...             ...       ...
# 195  146   97    5     1   3  ...                 0               0         0
# 233  214  180    4     0   1  ...                 1               1         2
# 157  143  143   16     9   3  ...                 2               0         6
# 95   136   88    6     2   4  ...                 0               0         1
# 338  231  127   13     4   2  ...                 3               2         2
#
#      PRI.PANAL  PVEM.PANAL  COALICION  CANDIDATO.NO.REGISTRADO  VOTOS.NULOS  \
# 97           0           0         69                        0           10
# 84           0           0        152                        0            7
# 327          0           0        110                        0            1
# 295          2           0        121                        0            5
# 120          0           0        151                        1           11
# ..         ...         ...        ...                      ...          ...
# 195          0           0        102                        0           13
# 233          0           0        186                        0            1
# 157          0           0        163                        0           12
# 95           0           0         92                        0            6
# 338          1           0        138                        0            5
#
#      TOTAL.VOTOS.VALIDOS  VOTACION.TOTAL.EMITIDA
# 97                   221                     231
# 84                   363                     370
# 327                  207                     208
# 295                  209                     214
# 120                  354                     366
# ..                   ...                     ...
# 195                  259                     272
# 233                  406                     407
# 157                  338                     350
# 95                   254                     260
# 338                  391                     396
#
# [92 rows x 23 columns]

# %%
random_v = randint(20,100)
if random_v > mf.shape[0]:
    random_v = mf.shape[0]

ms = ms.append(mf.sample(random_v))
mf = mf[~mf.isin(ms)]
mf = mf.loc[mf["LLEGADA"].notnull()]
# ms.to_excel("Files/Exports/PAQUETES.xlsx")
ms.to_csv("Files/Exports/PAQUETES.csv", index=False)
ms
# Out:
#      LLEGADA               DISTRITO.LOCAL              MUNICIPIO  SECCION  \
# 315    280.0            OBREGON SUR XV                    CAJEME    901.0
# 96     261.0                GUAYMAS XIII                 GUAYMAS   1056.0
# 152    104.0     HERMOSILLO NORESTE X                 HERMOSILLO    418.0
# 261     50.0            NOGALES SUR V                    NOGALES   1387.0
# 360     23.0  SAN LUIS RIO COLORADO I      SAN LUIS RIO COLORADO    667.0
# ..       ...                          ...                    ...      ...
# 68     161.0               ETCHOJOA XX                  ETCHOJOA   1169.0
# 66     314.0               ETCHOJOA XX                   NAVOJOA   1291.0
# 168     30.0    HERMOSILLO NOROESTE VIII              HERMOSILLO   1340.0
# 324    302.0        OBREGON SURESTE XVI                   CAJEME    883.0
# 23     181.0                CABORCA III                SANTA ANA    256.0
#
#         CASILLA    PAN    PRI   PRD  PVEM   PT  ...  ENCUENTRO.SOCIAL  \
# 315  CONTIGUA 3   87.0  150.0   8.0   6.0  3.0  ...               7.0
# 96       BASICA  106.0   98.0   2.0   1.0  6.0  ...               3.0
# 152  CONTIGUA 1  189.0  204.0   7.0   3.0  1.0  ...               3.0
# 261      BASICA   55.0   88.0   4.0   6.0  2.0  ...               3.0
# 360      BASICA  135.0   84.0   9.0   4.0  0.0  ...               8.0
# ..          ...    ...    ...   ...   ...  ...  ...               ...
# 68       BASICA  138.0  201.0  47.0   0.0  3.0  ...               0.0
# 66   CONTIGUA 1  138.0  158.0   7.0   0.0  3.0  ...               3.0
# 168  CONTIGUA 1  112.0  105.0   9.0   4.0  5.0  ...               4.0
# 324  CONTIGUA 1   71.0  130.0   4.0   5.0  7.0  ...               5.0
# 23   CONTIGUA 1  155.0  182.0   2.0   0.0  3.0  ...               0.0
#
#      PRI.PVEM.PANAL  PRI.PVEM  PRI.PANAL  PVEM.PANAL  COALICION  \
# 315             0.0       0.0        0.0         0.0      157.0
# 96              0.0       0.0        0.0         0.0      102.0
# 152             4.0       4.0        0.0         0.0      217.0
# 261             1.0       0.0        1.0         0.0       96.0
# 360             0.0       4.0        0.0         0.0       95.0
# ..              ...       ...        ...         ...        ...
# 68              2.0       0.0        0.0         0.0      209.0
# 66              0.0       1.0        2.0         0.0      170.0
# 168             0.0       1.0        0.0         0.0      113.0
# 324             0.0       3.0        0.0         0.0      139.0
# 23              0.0       2.0        0.0         0.0      190.0
#
#      CANDIDATO.NO.REGISTRADO  VOTOS.NULOS  TOTAL.VOTOS.VALIDOS  \
# 315                      0.0          5.0                277.0
# 96                       0.0         13.0                244.0
# 152                      2.0         13.0                419.0
# 261                      0.0         11.0                175.0
# 360                      0.0          7.0                262.0
# ..                       ...          ...                  ...
# 68                       0.0         11.0                399.0
# 66                       0.0         11.0                323.0
# 168                      1.0          5.0                251.0
# 324                      0.0          2.0                242.0
# 23                       0.0          1.0                353.0
#
#      VOTACION.TOTAL.EMITIDA
# 315                   282.0
# 96                    257.0
# 152                   434.0
# 261                   186.0
# 360                   269.0
# ..                      ...
# 68                    410.0
# 66                    334.0
# 168                   257.0
# 324                   244.0
# 23                    354.0
#
# [171 rows x 23 columns]
